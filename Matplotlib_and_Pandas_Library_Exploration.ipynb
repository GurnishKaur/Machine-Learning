# %% [markdown]
# <a href="https://colab.research.google.com/github/GurnishKaur/Machine-Learning/blob/main/Matplotlib_and_Pandas_Library_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `Matplotlib library`
#
#
# ---
#
#
# `Matplotlib is a cross-platform, data visualization and graphical plotting library for Python and its numerical extension NumPy.`

# %% [markdown]
# # Bar plot

# %%
# Plot a bar plot

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(10)

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', 'purple', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:purple', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit count')
ax.set_title('Fruit count by fruit type and color')
ax.legend(title='Fruit color')

plt.show()

# %% [markdown]
# # Pie Chart

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Hamburger', 'Pasta', 'Coffee', 'Tea'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()

plt.rcParams["figure.figsize"] = (10,8)

ax1.pie(sizes, explode=explode, labels=labels, 
        shadow=True)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
array = [23, 56, 78, 90, 100, 52, 18]

#Question1 = What is the range of the above array?
# Answer1 = (min, max)

# %% [markdown]
# #` 3D Scatter Plot`

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(1000)

plt.rcParams["figure.figsize"] = (10,12)


def random_range(n, vmin, vmax):
    """
    a = [1, 2, 6, 9, 0, 13, 17, 45, 90, 102]
    Helper function to make an array of random numbers having shape (n, 1)
    with each number distributed Uniform(vmin, vmax).
    """
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for m, zlow, zhigh in [('o', -50, -25), ('^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(19680801)
plt.rcParams["figure.figsize"] = (10,7.5)
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots()
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set(xlabel='entry a', ylabel='entry b')

plt.show()

# %% [markdown]
# ##` Multiple Visualizations`

# %%
def currency(x, pos):
    """The two arguments are the value and tick position"""
    if x >= 1e6:
        s = '${:1.1f}M'.format(x*1e-6)
    else:
        s = '${:1.0f}K'.format(x*1e-3)
    return s


plt.rcParams["figure.figsize"] = (12,10)
data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 135841.99,
        'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)


fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

# Add a vertical line, here we set the style in the function call
ax.axvline(group_mean, ls='dashdot', color='purple')

# Annotate new companies
for group in [3, 5, 8]:
    ax.text(145000, group, "New Company", fontsize=10,
            verticalalignment="bottom")

# Now we move our title up since it's getting a little cramped
ax.title.set(y=1.05)

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')

ax.set_xticks([0, 25e3, 50e3, 75e3, 100e3, 125e3])
#fig.subplots_adjust(right=.1)

plt.show()

# %% [markdown]
# # `Pandas Library`
#
#
#
# ---
#
#
# `pandas library helps you to carry out your entire data analysis workflow in Python.`

# %% [markdown]
# # `Create DataFrame from dictionary`

# %%
import pandas as pd

#dictionary
mydictionary = {'physics': [68, 74, 77, 78],
     'chemistry': [84, 56, 73, 69],
     'algebra': [78, 88, 82, 87]}

df = pd.DataFrame(mydictionary)
print(df)
# Out:
#    physics  chemistry  algebra
# 0       68         84       78
# 1       74         56       88
# 2       77         73       82
# 3       78         69       87

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # `Get info from the dataframe`

# %%
df = pd.DataFrame(
    [['abc', 22],
    ['xyz', 25],
    ['pqr', 31]],
    columns=['name', 'age'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %% [markdown]
# # `Check if the dataframe is empty or not`

# %%
isempty = df.empty
print('Is the DataFrame empty :', isempty)
# Out:
# Is the DataFrame empty : False

# %% [markdown]
# # `Get shape of the dataframe`

# %%
#get dataframe shape
shape = df.shape

# %%
print(shape)
# Out:
# (3, 2)

# %%
df
# Out:
#   name  age
# 0  abc   22
# 1  xyz   25
# 2  pqr   31

# %%
#number of rows in dataframe
num_rows = df.shape[0]
#print(df)
print(num_rows)
# Out:
# 3

# %%
# number of columns of the dataframe
print(df.shape[1])
# Out:
# 2

# %% [markdown]
# # `Get maximum value`

# %%
# calculate max along columns

#dictionary
mydictionary = {'physics': [68, 74, 77, 78],
     'chemistry': [84, 56, 73, 69],
     'algebra': [78, 88, 82, 87]}

df = pd.DataFrame(mydictionary)
print(df)

max_value = df.max()
print('\nMaximum Value\n------')
print(max_value)
# Out:
#    physics  chemistry  algebra
# 0       68         84       78
# 1       74         56       88
# 2       77         73       82
# 3       78         69       87
#
# Maximum Value
# ------
# physics      78
# chemistry    84
# algebra      88
# dtype: int64

# %%
max_value= df.max(axis=1)
print('\nMaximum Value\n------')
print(max_value)
# Out:
# Maximum Value
# ------
# 0    84
# 1    88
# 2    82
# 3    87
# dtype: int64

# %% [markdown]
# # `delete column of the dataframe`

# %%
del df['chemistry']

# %%
df
# Out:
#    physics  algebra
# 0       68       78
# 1       74       88
# 2       77       82
# 3       78       87
